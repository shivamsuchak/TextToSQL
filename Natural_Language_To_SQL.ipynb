# %% [markdown]
# ##Creating a dummy Database

# %%
# %pip install sqlalchemy

# %%
import os
import random
from datetime import date, timedelta
from sqlalchemy.orm import declarative_base, relationship, sessionmaker
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey, Date, Float


Base = declarative_base()

class Customer(Base):
    __tablename__ = 'customers'
    id = Column(Integer, primary_key=True)
    name = Column(String)
    email = Column(String, unique=True)
    orders = relationship("Order", back_populates="customer")

class Product(Base):
    __tablename__ = 'products'
    id = Column(Integer, primary_key=True)
    name = Column(String)
    price = Column(Float)
    orders = relationship("Order", back_populates="product")

class Order(Base):
    __tablename__ = 'orders'
    id = Column(Integer, primary_key=True)
    customer_id = Column(Integer, ForeignKey('customers.id'))
    product_id = Column(Integer, ForeignKey('products.id'))
    quantity = Column(Integer)
    order_date = Column(Date)

    customer = relationship("Customer", back_populates="orders")
    product = relationship("Product", back_populates="orders")

# %% [markdown]
# ###Inserting data

# %%
if not os.path.exists('example.db'):

  # Create SQLite engine
  engine = create_engine('sqlite:///example.db')
  Base.metadata.create_all(engine)

  # Session
  Session = sessionmaker(bind=engine)
  session = Session()

  # Sample data
  customer_names = ["Alice", "Bob", "Charlie", "Diana", "Edward", "Fiona", "George", "Hannah", "Ian", "Julia"]
  product_names = ["Laptop", "Smartphone", "Tablet", "Headphones", "Monitor", "Keyboard", "Mouse", "Printer", "Camera", "Router"]
  prices = [1200, 800, 300, 150, 250, 100, 50, 200, 500, 120]

  # Add customers
  customers = [Customer(name=name, email=f"{name.lower()}@example.com") for name in customer_names]
  session.add_all(customers)

  # Add products
  products = [Product(name=name, price=price) for name, price in zip(product_names, prices)]
  session.add_all(products)

  # Commit customers and products so we can reference them by ID
  session.commit()

  # Add 10 orders
  for i in range(10):
      order = Order(
          customer_id=random.choice(customers).id,
          product_id=random.choice(products).id,
          quantity=random.randint(1, 5),
          order_date=date(2024, 5, 1) + timedelta(days=i)
      )
      session.add(order)

  session.commit()
  session.close()
print('Database already exists')

# %%
import sqlite3
import contextlib


@contextlib.contextmanager
def sql_cursor(readonly=True):
  conn = sqlite3.connect('example.db')
  cursor = conn.cursor()
  try:
    yield cursor
    if not readonly:
      conn.commit()
  except Exception:
    if not readonly:
      conn.rollback()
    raise
  finally:
    cursor.close()
    conn.close()
# Out:
# (1, 'Alice', 'alice@example.com')
# (2, 'Bob', 'bob@example.com')
# (3, 'Charlie', 'charlie@example.com')
# (4, 'Diana', 'diana@example.com')
# (5, 'Edward', 'edward@example.com')
# (6, 'Fiona', 'fiona@example.com')
# (7, 'George', 'george@example.com')
# (8, 'Hannah', 'hannah@example.com')
# (9, 'Ian', 'ian@example.com')
# (10, 'Julia', 'julia@example.com')

# %%
with sql_cursor() as cursor:
  cursor.execute('SELECT * FROM customers')
  for row in cursor.fetchall():
    print(row)

# %% [markdown]
# #Natural Language to SQL

# %%
# %pip install -U -q langchain-community langchain-core langgraph langchain-groq
# %pip install goolge
# Out:
# Nice to meet you! I am LLaMA, an AI assistant developed by Meta AI that can understand and respond to human input in a conversational manner. I'm not a human, but a computer program designed to simulate conversation, answer questions, and even generate text based on the input I receive.
#
# I'm constantly learning and improving my responses based on the interactions I have with users like you. My primary goal is to assist and provide helpful information, answer questions, and engage in productive conversations.
#
# So, what brings you here today? Do you have a specific topic in mind or would you like to chat about something random? I'm here to listen and respond!

# %%
# %pip install google.colab
# %load_ext autoreload
# %autoreload 2
# Out:
# sqlite
# ==============================
#
# ['customers', 'orders', 'products']
# ==============================
#
#
# CREATE TABLE customers (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	email VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	name	email
# 1	Alice	alice@example.com
# 2	Bob	bob@example.com
# 3	Charlie	charlie@example.com
# */
#
#
# CREATE TABLE orders (
# 	id INTEGER NOT NULL,
# 	customer_id INTEGER,
# 	product_id INTEGER,
# 	quantity INTEGER,
# 	order_date DATE,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(customer_id) REFERENCES customers (id),
# 	FOREIGN KEY(product_id) REFERENCES products (id)
# )
#
# /*
# 3 rows from orders table:
# id	customer_id	product_id	quantity	order_date
# 1	2	9	3	2024-05-01
# 2	6	5	3	2024-05-02
# 3	2	5	2	2024-05-03
# */
#
#
# CREATE TABLE products (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	price FLOAT,
# 	PRIMARY KEY (id)
# )
#
# /*
# 3 rows from products table:
# id	name	price
# 1	Laptop	1200.0
# 2	Smartphone	800.0
# 3	Tablet	300.0
# */

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq

# Load from .env
load_dotenv()
os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY')

llm = ChatGroq(model='llama3-70b-8192')  # correct model name
print(llm.invoke('who are you?').content)

# %%
from langchain_community.utilities.sql_database import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///example.db")

print(db.dialect)

print("=" * 30, "\n")
print(db.get_usable_table_names())
print("=" * 30, "\n")
print(db.get_table_info())

# %%
from typing_extensions import TypedDict
from pydantic import BaseModel, Field
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langgraph.graph import StateGraph, END


## Initial state
class AgentState(TypedDict):
    question: str
    sql_query: str
    query_result: str
    query_rows: list
    attempts: int
    relevance: str
    final_answer: str
    sql_error: bool

# %%
## Agent 1: Determines if the user NL-input relevant to the db schema

class CheckRelevance(BaseModel):
    relevance: str = Field(
        description="Indicates whether the question is related to the database schema. 'relevant' or 'not_relevant'."
    )

def check_relevance(state: AgentState):
    question = state["question"]
    print(f"Checking relevance of the question: {question}")
    system = """You are a highly skilled SQL expert. Your task is to evaluate whether a given natural language question is relevant to a database based on its schema.

    Use the schema below to determine whether the question can reasonably be answered using the available tables and columns.

    ---
    Schema:
    {schema}
    ---

    Instructions:
    1. Carefully read the user's question.
    2. Check whether the schema contains the necessary tables and columns to answer the question.
    3. If the question can be answered using the schema, respond with **"relevant"**.
    4. If the schema lacks the necessary information, respond with **"not_relevant"**.
    5. Your response must be either **"relevant"** or **"not_relevant"** only—do not explain or elaborate.

    Output Format:
    relevant
    or
    not_relevant
    """
    human = f"Question: {question}"
    check_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system),
            ("human", human),
        ]
    )

    llm = ChatGroq(model='llama-3.3-70b-versatile')
    structured_llm = llm.with_structured_output(CheckRelevance)
    relevance_checker = check_prompt | structured_llm
    try:
      relevance = relevance_checker.invoke({'schema': db.get_table_info()})
      state["relevance"] = relevance.relevance.lower().strip()
      print(f"Relevance determined: {state['relevance']}")
    except Exception as e:
      print(f"Error during relevance check: {e}")
      state["relevance"] = "not_relevant"
      state["sql_error"] = True
    return state

# %%
## Agent 2: Converts natural language to SQL queries

class ConvertToSQL(BaseModel):
    sql_query: str = Field(
        description="The SQL query corresponding to the user's natural language question."
    )


def convert_nl_to_sql(state: AgentState):
    question = state["question"]
    print(f"Converting question to SQL for user: {question}")
    system = """
    You are a highly skilled SQL generation assistant. Your task is to convert a user's natural language question into a valid, syntactically correct, and semantically meaningful SQL query using the correct {dialect} dialect.

    Follow these strict rules:

    1. **Use only the tables and columns provided in the schema below**. Do not invent or reference tables/columns that are not explicitly listed.
    2. **Understand the relationships between tables** (e.g., foreign keys, primary keys) and use JOINs accordingly where appropriate.
    3. **Avoid using `SELECT *`**. Instead, return only the specific columns that are relevant to answering the user's question.
    4. Use appropriate **filters, sorting, and grouping** based on the user's intent (e.g., time ranges, categories, totals).
    5. If necessary, use **aggregations** (COUNT, AVG, MAX, etc.) when the question asks for summaries or statistics.
    6. Maintain clarity and simplicity. Prioritize correctness over cleverness.

    Before generating the SQL:
    - Carefully analyze the user's question.
    - Infer any implicit intent (e.g., filtering, ordering) only if it logically follows from the question.
    - Never assume facts that are not supported by the schema or the question.

    Schema:
    {table_info}

    Now, generate the SQL query that answers the following user question:
    """.format(dialect=db.dialect, table_info=db.get_table_info())

    convert_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system),
            ("human", "Question: {question}"),
        ]
    )

    llm = ChatGroq(model='llama-3.3-70b-versatile')
    structured_llm = llm.with_structured_output(ConvertToSQL)
    sql_generator = convert_prompt | structured_llm
    try:
      result = sql_generator.invoke({"question": question})
      state["sql_query"] = result.sql_query.strip()
    except Exception as e:
      print(f"Failed to generate SQL: {e}")
      state["sql_query"] = ""
      state["sql_error"] = True
    print(f"Generated SQL query: {state['sql_query']}")
    return state

# %%
from langchain_community.tools import QuerySQLDatabaseTool
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate

## Agent 3: Executes generated SQL query -> retrieve the data from db -> returns updated state
def execute_query(state: AgentState):
    """Execute SQL query and update state based on outcome."""
    execute_query_tool = QuerySQLDatabaseTool(db=db)
    try:
        result = execute_query_tool.invoke(state["sql_query"])
        state["query_result"] = result
        state["sql_error"] = False
    except Exception as e:
        print(f"Error during SQL execution: {e}")
        state["sql_error"] = True
        state["query_result"] = str(e)
    return state

# %%
## Agent 4: Based on SQL result, generates NL answer
def generate_answer(state: AgentState):
    """Answer question using retrieved information as context."""
    template = PromptTemplate.from_template(
    """You are an intelligent data assistant. Your task is to help answer the user's natural language question by using the provided SQL query and its result.

    You will be given:
    1. The original user question.
    2. The SQL query that was generated to answer the question.
    3. The result returned by executing that SQL query.

    Use this information to provide a helpful, clear, and concise answer to the user's question. If the result is empty or insufficient to answer the question confidently, respond accordingly.

    ---
    Question: {question}
    SQL Query: {sql_query}
    SQL Result: {query_result}
    ---

    Final Answer:""")

    llm_chain = template | llm | StrOutputParser()
    answer = llm_chain.invoke({
        "question": state["question"],
        "sql_query": state["sql_query"],
        "query_result": state["query_result"]
    })
    state["final_answer"] = answer
    return state

# %%
## Agent 5: Generates funny response if the user's query is not relevent to the db
def generate_funny_response(state: AgentState):
    print("Generating a funny response for an unrelated question.")
    system = """
    You are a witty, charming, and funny assistant whose job is to entertain users when they ask questions unrelated to the database or when no relevant answer can be provided.

    Your responses should:
    - Be playful and light-hearted.
    - Stay appropriate and friendly.
    - Acknowledge that the question isn't answerable via the database.
    - Gently steer the user back on track with a smile (figuratively).

    You are not required to be helpful — just be delightfully unhelpful in a clever way.
    """

    human_message = f"""
    The user asked a question that is unrelated to the database:
    '{state['question']}'
    Craft a humorous and creative response."""

    funny_prompt = ChatPromptTemplate.from_messages([
        ("system", system),
        ("human", human_message),
    ])

    llm = ChatGroq(model='llama-3.3-70b-versatile')
    funny_response = funny_prompt | llm | StrOutputParser()
    message = funny_response.invoke({})
    state["final_answer"] = message
    print("Generated funny response.")
    return state

# %%
## Agent 6: Rewrites the og question if there isn't enough info
class RewrittenQuestion(BaseModel):
    question: str = Field(description="The rewritten question.")

def regenerate_query(state: AgentState):
    question = state["question"]
    print("Regenerating the SQL query by rewriting the question.")
    system = """
    You are an expert in SQL and natural language understanding.

    Your task is to **rewrite a user's natural language question** so that:
    - It is clear, complete, and unambiguous.
    - It is optimized to be converted into a precise and valid SQL query.
    - All necessary details (e.g. filters, relationships between tables, required joins, and any implied logic) are included.
    - The reformulated version preserves the intent and meaning of the original question but improves its structure for programmatic interpretation.

    Avoid making assumptions not supported by the original question or schema.
    """

    rewrite_prompt = ChatPromptTemplate.from_messages([
        ("system", system),
        ("human", "Original Question: {question}\n\nRewrite this question to make it clearer and more suitable for SQL generation, including all relevant details.")
    ])

    llm = ChatGroq(model='llama-3.3-70b-versatile', temperature=0)
    structured_llm = llm.with_structured_output(RewrittenQuestion)
    rewriter = rewrite_prompt | structured_llm

    rewritten = rewriter.invoke({"question": question})
    state["rewritten_question"] = rewritten.question
    state["attempts"] = state.get("attempts", 0) + 1
    print(f"Rewritten question: {state['rewritten_question']}")
    return state

# %%
## Conditionnal nodes
def end_max_iter(state: AgentState):
    print("Maximum attempts reached. Ending the workflow.")
    state["query_result"] = "Please try again."
    return state

def router(state: AgentState):
    print("Routing based on relevance...")
    if state["relevance"].lower() == "relevant":
        return "convert_to_sql"
    else:
        return "generate_funny_response"

def check_attempts(state: AgentState):
    print(f"Attempt #{state['attempts']}")
    if state["attempts"] < 3:
        return "convert_to_sql"
    else:
        return "end_max_iter"

def execute_sql(state: AgentState):
    print("Routing based on SQL execution result...")
    if not state.get("sql_error", False):
        return "generate_answer"
    else:
        return "regenerate_query"

# %%
## Constructing the the Graph
from langgraph.graph import StateGraph, END

workflow = StateGraph(AgentState)

# Add nodes
workflow.add_node("check_relevance", check_relevance)
workflow.add_node("convert_to_sql", convert_nl_to_sql)
workflow.add_node("execute_sql", execute_query)
workflow.add_node("generate_answer", generate_answer)
workflow.add_node("generate_funny_response", generate_funny_response)
workflow.add_node("regenerate_query", regenerate_query)
workflow.add_node("end_max_iter", end_max_iter)

# Conditional logic
workflow.add_conditional_edges(
    "check_relevance",
    router,
    {
        "convert_to_sql": "convert_to_sql",
        "generate_funny_response": "generate_funny_response",
    },
)

workflow.add_edge("convert_to_sql", "execute_sql")

workflow.add_conditional_edges(
    "execute_sql",
    execute_sql,
    {
        "generate_answer": "generate_answer",
        "regenerate_query": "regenerate_query",
    },
)

workflow.add_conditional_edges(
    "regenerate_query",
    check_attempts,
    {
        "convert_to_sql": "convert_to_sql",
        "end_max_iter": "end_max_iter",
    },
)

# Terminal paths
workflow.add_edge("generate_answer", END)
workflow.add_edge("generate_funny_response", END)
workflow.add_edge("end_max_iter", END)

# Start point
workflow.set_entry_point("check_relevance")

# Compile
app = workflow.compile()
# Out:
# Checking relevance of the question: check adventure database and give me all the columns it has, and one example of row
# Relevance determined: not_relevant
# Routing based on relevance...
# Generating a funny response for an unrelated question.
# Generated funny response.
# Assistant: It seems like you're on a thrilling quest for adventure... in the database realm. I'm afraid our trusty database map doesn't quite lead to the "Adventure Database" you're seeking. It's like trying to find a pirate's treasure using a map that only shows the location of the nearest coffee shops.
#
# As I rummage through our database archives (which are actually just a bunch of digital shelves filled with 1s and 0s), I realize that the "Adventure Database" is more of a mythical creature – like a unicorn that only exists in the imagination of daring explorers like yourself.
#
# However, if you're looking for a real adventure, I can offer you a thrilling example of a completely made-up database row:
#
# | Column Name | Example Value |
# | --- | --- |
# | Brave Quest | Slaying the Dragon of Procrastination |
# | Fearless Hero | Captain Caffeine |
# | Magical Artifact | The Sword of Productivity |
# | Daring Feat | Completing a to-do list in under an hour |
#
# Now, if you'll excuse me, I have to attend to some urgent database business – like making sure our servers don't get overrun by mischievous bands of digital goblins.
#
# Perhaps you could try rephrasing your question or seeking a different adventure in our database realms? I promise it'll be a quest worth undertaking!
#
# Checking relevance of the question: what is the currenycode for bb countryregioncode
# Relevance determined: not_relevant
# Routing based on relevance...
# Generating a funny response for an unrelated question.
# Generated funny response.
# Assistant: It seems like you're on a top-secret mission to crack the code (literally!). Unfortunately, our database is like a treasure chest that's locked and only contains information about, well, non-secret stuff.
#
# But fear not, intrepid explorer! I can try to help you decipher the mystery of the "BB" country/region code. *puts on detective hat*
#
# Hmmm... Could it be that "BB" stands for a far-off land called "Barbados"? Or perhaps it's a cryptic message pointing to a mystical realm known as "Bermuda" (the triangle of confusion, maybe?)?
#
# Alas, without more clues, I'm afraid I'll have to leave you hanging, like a secret agent without a decent martini (shaken, not stirred, of course!).
#
# If you're ready to abandon your covert operation and return to the world of factual information, I'd be delighted to assist you with a different question. Just don't tell anyone, but I think the answer might be "BB" = "Barbados" (ISO 3166-1 alpha-2 code, if you want to get all fancy about it).

# %%
from IPython.display import display, Markdown

# Get the Mermaid diagram code directly
mermaid_code = app.get_graph().draw_mermaid()

# Display using Markdown
mermaid_markdown = f"""
```mermaid
{mermaid_code}
```
"""

display(Markdown(mermaid_markdown))
# Out:
# ```mermaid
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	check_relevance(check_relevance)
# 	convert_to_sql(convert_to_sql)
# 	execute_sql(execute_sql)
# 	generate_answer(generate_answer)
# 	generate_funny_response(generate_funny_response)
# 	regenerate_query(regenerate_query)
# 	end_max_iter(end_max_iter)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> check_relevance;
# 	check_relevance -.-> convert_to_sql;
# 	check_relevance -.-> generate_funny_response;
# 	convert_to_sql --> execute_sql;
# 	execute_sql -.-> generate_answer;
# 	execute_sql -.-> regenerate_query;
# 	regenerate_query -.-> convert_to_sql;
# 	regenerate_query -.-> end_max_iter;
# 	end_max_iter --> __end__;
# 	generate_answer --> __end__;
# 	generate_funny_response --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
#
# ```

# %%
from IPython.display import Image, display

try:
  display(Image(app.get_graph(xray=True).draw_mermaid_png(max_retries=5, retry_delay=2.0)))
except:
  pass

# %%
# display(Image(app.get_graph(xray=True).draw_mermaid_png(max_retries=5, retry_delay=2.0)))

# %%
# Initialize state
state = {
    "question": "",
    "chat_history": [], # adding memory
    "sql_query": "",
    "query_result": "",
    "query_rows": [],
    "attempts": 0,
    "relevance": "",
    "final_answer": "",
    "sql_error": False,
}


while True:
    user_input = input("User: ").strip()
    if user_input.lower() in ["exit", "quit"]:
        print("Conversation ended.")
        break

    state["question"] = user_input
    state["attempts"] = 0  # reset attempts each new question

    result = app.invoke(state)

    answer = result.get("final_answer", "No response available.")

    print(f"Assistant: {answer}\n")

    state["chat_history"].append({"user": user_input, "assistant": answer})
# Out:
# Checking relevance of the question: Most sold product?
# Relevance determined: relevant
# Routing based on relevance...
# Converting question to SQL for user: Most sold product?
# Generated SQL query: SELECT p.name, SUM(o.quantity) as total_quantity FROM orders o JOIN products p ON o.product_id = p.id GROUP BY p.name ORDER BY total_quantity DESC LIMIT 1
# Routing based on SQL execution result...
# Assistant: The most sold product is the "Monitor" with a total of 10 units sold.
#
# Checking relevance of the question: by which customer?
# Relevance determined: relevant
# Routing based on relevance...
# Converting question to SQL for user: by which customer?
# Generated SQL query: SELECT T1.name FROM customers AS T1 INNER JOIN orders AS T2 ON T1.id = T2.customer_id;
# Routing based on SQL execution result...
# Assistant: Based on the provided SQL query and result, the answer to the user's query "by which customer?" is:
#
# The customers who have made orders are Bob, Fiona, George, Charlie, and Diana.
#
# Checking relevance of the question: what are the products ordered by Diana
# Relevance determined: not_relevant
# Routing based on relevance...
# Generating a funny response for an unrelated question.
# Generated funny response.
# Assistant: Diana, the mysterious shopper. I've dug deep into the vaults of my imagination, but alas, it seems the database is as tight-lipped as a secret agent about her shopping habits.
#
# However, I can tell you that if Diana's shopping cart were a magical kingdom, it would probably be filled with enchanted forest fruits, moonbeams, and the occasional unicorn horn (because, why not?). But, sadly, our database doesn't deal in mythical creatures or royal shopping sprees.
#
# If you're looking for actual information, I'm afraid you'll have to conjure up a different question, one that's a bit more... down-to-earth. But hey, a shopper can dream, right? What's your next question? Perhaps one that'll lead us on a wild adventure through the realms of knowledge?
#
# Checking relevance of the question: which product has the highest price and who bought it?
# Relevance determined: relevant
# Routing based on relevance...
# Converting question to SQL for user: which product has the highest price and who bought it?
# Generated SQL query: SELECT p.name, c.name FROM products p JOIN orders o ON p.id = o.product_id JOIN customers c ON o.customer_id = c.id ORDER BY p.price DESC LIMIT 1
# Routing based on SQL execution result...
# Assistant: I apologize, but the provided SQL result is insufficient to answer the user's question confidently. The result only includes the customer's name "George", but it does not include the product name or price information.
#
# To answer the question, we need to know the product with the highest price, which is missing in the result. I would recommend re-running the query to include the product name and price in the result.
#
# Checking relevance of the question: hello
# Relevance determined: not_relevant
# Routing based on relevance...
# Generating a funny response for an unrelated question.
# Generated funny response.
# Assistant: Hello there, friend. It seems like you've stumbled upon the digital equivalent of a coffee shop, where the barista (me) is happy to chat, but not quite sure what to put in your cup. You've asked a question that's as vague as a fortune cookie message, and I must admit, I'm intrigued.
#
# Unfortunately, our trusty database is about as helpful as a chocolate teapot in this situation. But don't worry, I'm not here to leave you hanging like a participant in a game of digital limbo. Instead, I'll offer you a virtual cookie and a wink, saying, "Hello, indeed! Now, what's on your mind? Want to play a game, have a chat, or maybe even ask a question that'll unlock the secrets of the universe (or at least, our database)?"
#
# Checking relevance of the question: highest price product?
# Relevance determined: relevant
# Routing based on relevance...
# Converting question to SQL for user: highest price product?
# Generated SQL query: SELECT name, price FROM products ORDER BY price DESC LIMIT 1
# Routing based on SQL execution result...
# Assistant: The highest price product is the "Laptop", which costs $1200.
#
# Checking relevance of the question: who bought it?
# Relevance determined: not_relevant
# Routing based on relevance...
# Generating a funny response for an unrelated question.
# Generated funny response.
# Assistant: The age-old question: "who bought it?" Well, I've consulted the ancient tomes, gazed into the crystal ball, and even asked the office cat for her expertise (she's very wise, you know). And the verdict is... *dramatic pause* ...I have no idea!
#
# It seems the mystery of "who bought it" is a puzzle for the ages, a enigma wrapped in a riddle, inside a cryptic message that only the most skilled detectives can decipher. Alas, my database superpowers don't extend to solving crimes of unknown purchases.
#
# But fear not, dear user! For I can offer you a few theories: perhaps it was a secret society of stealthy shoppers, or maybe it was a time-traveling buyer from the year 3050. Or, you know, it could've just been your neighbor, Bob.
#
# If you're still curious, I can suggest some top-notch detective work: ask around, check the receipts, or (gasp!) try using your best Sherlock Holmes impression. Meanwhile, I'll just be over here, enjoying the thrill of the unknown and wondering who ate the last donut in the break room.
#
# Checking relevance of the question:
# Relevance determined: not_relevant
# Routing based on relevance...
# Generating a funny response for an unrelated question.
# Generated funny response.
# Assistant: It seems like you've asked a question that's taken a delightful detour from our database's neighborhood. Don't worry, I won't leave you hanging like a plot twist in a mystery novel – I'll just acknowledge that we've reached the end of our factual freeway.
#
# Imagine we're on a road trip, and our trusty GPS (which is really just me in a fancy hat) has announced, "Recalculating..." – but instead of giving us new directions, it's just playing a catchy tune on repeat. That's kind of where we are right now.
#
# If you're ready to get back on track (or should I say, back on the database highway?), I'd be happy to help with a different question that's more within our realm of expertise. But if you'd rather keep exploring the uncharted territories of curiosity, I can certainly engage in a fun conversation – just don't expect me to pull out any factual maps or compasses!
#
# Checking relevance of the question:
# Relevance determined: not_relevant
# Routing based on relevance...
# Generating a funny response for an unrelated question.
# Generated funny response.
# Assistant: It seems like you've asked a question that's as elusive as a unicorn on a unicorn hunt. Unfortunately, our trusty database doesn't have a map to lead us to the answer, but I can offer you a treasure map to nowhere in particular.
#
# If you're feeling adventurous, we could play a game of "Question Limbo" – how low can we go before we find a question that's actually related to the database? Or we could have a chat about the meaning of life, the best flavor of ice cream, or the airspeed velocity of an unladen swallow.
#
# So, what do you say? Shall we dance around the database, singing a merry tune of unrelated questions, or would you like to try again and see if we can't find something a bit more... database-y?
#
# Checking relevance of the question:
# Relevance determined: not_relevant
# Routing based on relevance...
# Generating a funny response for an unrelated question.
# Generated funny response.
# Assistant: It seems like you've asked a question that's as elusive as a unicorn's favorite snack. Sadly, our trusty database doesn't have a secret portal to answer such mystical inquiries. But don't worry, I'm here to distract you with some witty banter instead!
#
# Imagine we're in a quirky café, sipping on "Unanswerable Questions" lattes. The barista just whispered a joke in my ear: Why did the question go to therapy? Because it was feeling a little "unresolved"!
#
# Now, shall we get this conversation back on track, or would you like to explore more uncharted territories of whimsy and wonder? The choice is yours, brave adventurer!
